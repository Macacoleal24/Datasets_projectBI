# %%
url1 = "https://raw.githubusercontent.com/edavgaun/Inteligencia-de-negocios/refs/heads/master/Datasets/Data_tests/Spotify/spotify_dataset.csv"
url2 = "https://raw.githubusercontent.com/Macacoleal24/Datasets_projectBI/refs/heads/main/Global_Music_Streaming_Listener_Preferences.csv"
url3 = "https://raw.githubusercontent.com/Macacoleal24/Datasets_projectBI/refs/heads/main/spotify_data%20clean.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(url1)
df2 = pd.read_csv(url3)

# %% [markdown]
# column Dataset profe= Index,Highest Charting Position,Number of Times Charted,Week of Highest Charting,Song Name,Streams,Artist,Artist Followers,Song ID,Genre,Release Date,Weeks Charted,Popularity,Danceability,Energy,Loudness,Speechiness,Acousticness,Liveness,Tempo,Duration (ms),Valence,Chord
# column Dataset spotify= track_id,track_name,track_number,track_popularity,explicit,artist_name,artist_popularity,artist_followers,artist_genres,album_id,album_name,album_release_date,album_total_tracks,album_type,track_duration_min
# Column Dataset Global_Music_Streaming_Listener_Preferences= User_ID,Age,Country,Streaming Platform,Top Genre,Minutes Streamed Per Day,Number of Songs Liked,Most Played Artist,Subscription Type,Listening Time (Morning/Afternoon/Night),Discover Weekly Engagement (%),Repeat Song Rate (%)

# %%
df1.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# ...

# %%
df1.tail()
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name    Streams  \
# 1551   2019-12-27--2020-01-03                           New Rules  4,630,675
# 1552   2019-12-27--2020-01-03                  Cheirosa - Ao Vivo  4,623,030
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)  4,620,876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk  4,607,385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]  4,595,450
#
#                              Artist Artist Followers                 Song ID  \
# ...

# %%
df1.columns
df2.columns
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'explicit', 'artist_name', 'artist_popularity', 'artist_followers',
#        'artist_genres', 'album_id', 'album_name', 'album_release_date',
#        'album_total_tracks', 'album_type', 'track_duration_min'],
#       dtype='object')

# %%
df1.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Index                      1556 non-null   int64
#  1   Highest Charting Position  1556 non-null   int64
#  2   Number of Times Charted    1556 non-null   int64
#  3   Week of Highest Charting   1556 non-null   object
#  4   Song Name                  1556 non-null   object
#  5   Streams                    1556 non-null   object
#  6   Artist                     1556 non-null   object
#  7   Artist Followers           1556 non-null   object
#  8   Song ID                    1556 non-null   object
#  9   Genre                      1556 non-null   object
#  10  Release Date               1556 non-null   object
#  11  Weeks Charted              1556 non-null   object
#  12  Popularity                 1556 non-null   object
# ...

# %%
df1.dtypes
df2.dtypes
# Out:
# track_id               object
# track_name             object
# track_number            int64
# track_popularity        int64
# explicit                 bool
# artist_name            object
# artist_popularity       int64
# artist_followers        int64
# artist_genres          object
# album_id               object
# album_name             object
# album_release_date     object
# album_total_tracks      int64
# album_type             object
# track_duration_min    float64
# dtype: object

# %%
#Merge por ID
df1 = df1.rename(columns={"Song Name": "track_name"})
df1 = df1.rename(columns={"Song ID": "track_ID"})
df1 = df1.rename(columns={"Release Date": "album_release_date"})
df2 = df2.rename(columns={"artist_name": "Artist"})

# %%
df1.columns
# Out:
# Index(['Index', 'Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'track_name', 'Streams', 'Artist',
#        'Artist Followers', 'track_ID', 'Genre', 'album_release_date',
#        'Weeks Charted', 'Popularity', 'Danceability', 'Energy', 'Loudness',
#        'Speechiness', 'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)',
#        'Valence', 'Chord'],
#       dtype='object')

# %%
df1.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                         track_name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                track_ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# ...

# %%
df2.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit     Artist  artist_popularity  \
# 0             4                 0      True      Diplo                 77
# 1             1                 0      True   Yelawolf                 64
# 2             1                 4      True  Riff Raff                 48
# 3             8                30      True      Diplo                 77
# 4             2                 0      True    Rumelis                 48
#
#    artist_followers                      artist_genres  \
# ...

# %%
df2["artist_genres"].isnull().sum()
# Out:
# np.int64(3361)

# %%
#Revisamos la cantidad de null en el data set del profesor
df1.isnull().sum()
# Out:
# Index                        0
# Highest Charting Position    0
# Number of Times Charted      0
# Week of Highest Charting     0
# track_name                   0
# Streams                      0
# Artist                       0
# Artist Followers             0
# track_ID                     0
# Genre                        0
# album_release_date           0
# Weeks Charted                0
# Popularity                   0
# Danceability                 0
# Energy                       0
# Loudness                     0
# Speechiness                  0
# Acousticness                 0
# Liveness                     0
# Tempo                        0
# Duration (ms)                0
# Valence                      0
# Chord                        0
# dtype: int64

# %%
#Revisamos la cantidad de null en el data set de Spotify
df2.isnull().sum()
# Out:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# Artist                   3
# artist_popularity        0
# artist_followers         0
# artist_genres         3361
# album_id                 0
# album_name               0
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64

# %%
#limpiamos los espacios en blanco y convertimos a minúsculas
df1["track_name"] = df1["track_name"].str.lower().str.strip()
df2["track_name"] = df2["track_name"].str.lower().str.strip()

# %%
df1["Popularity"].head()
# Out:
# 0    100
# 1     99
# 2     99
# 3     98
# 4     96
# Name: Popularity, dtype: object

# %%
df2.head(4369)
# Out:
#                     track_id  \
# 0     3EJS5LyekDim1Tf5rBFmZl
# 1     1oQW6G2ZiwMuHqlPpP27DB
# 2     7mdkjzoIYlf1rx9EtBpGmU
# 3     67rW0Zl7oB3qEpD5YWWE5w
# 4     15xptTfRBrjsppW0INUZjf
# ...                      ...
# 4364  0P6AWOA4LG1XOctzaVu5tt
# 4365  3qGHAKgjQruzj6doKkyEb5
# 4366  7FlHNJT4TC120CDvFOHzei
# 4367  5w3NgfV8v1nNZFLUBlGHIL
# 4368  3Wrjm47oTz2sjIgck11l5e
#
#                                              track_name  track_number  \
# 0                         trippy mane (ft. project pat)             4
# 1                                                  omg!             1
# 2                                           hard 2 find             1
# 3       still get like that (ft. project pat & starrah)             8
# 4                                 ride me like a harley             2
# ...                                                 ...           ...
# 4364                       the weekend - funk wav remix             1
# ...

# %%
df1.columns = df1.columns.str.strip()

# %%
#Normalizamos los nombres de las columnas quitando los espacios en blanco
df1.columns = df1.columns.str.strip()
cols = [
    "Index",
    "Highest Charting Position ",
    "Week of Highest Charting",
    "Artist Followers",
    "Weeks Charted",
    "Energy",
    "Loudness",
    "Liveness",
    "Chord",
    "Tempo",
    "Valence",
    "Speechiness",
    "Acousticness",
]

# %%
cols = [c.strip() for c in cols]
df1 = df1.drop(columns=cols, errors='ignore')

# %%
# Eliminamos las columnas que no tienen uso en el análisis
df1 = df1.drop(columns=[
    "Index",
    "Highest Charting Position",
    "Week of Highest Charting",
    "Artist Followers",
    "Weeks Charted",
    "Energy",
    "Loudness",
    "Liveness",
    "Chord",
    "Tempo",
    "Valence",
    "Speechiness",
    "Acousticness"
])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Eliminamos las columnas que no tienen uso en el análisis
# ----> 2 df1 = df1.drop(columns=[
#       3     "Index",
#       4     "Highest Charting Position",
#       5     "Week of Highest Charting",
#       6     "Artist Followers",
#       7     "Weeks Charted",
#       8     "Energy",
#       9     "Loudness",
#      10     "Liveness",
#      11     "Chord",
#      12     "Tempo",
#      13     "Valence",
#      14     "Speechiness",
#      15     "Acousticness"
#      16 ])
#
# File c:\Users\laelm\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
# ...

# %%
df1.head()
# Out:
#    Number of Times Charted                         track_name     Streams  \
# 0                        8                            beggin'  48,633,449
# 1                        3          stay (with justin bieber)  47,248,719
# 2                       11                           good 4 u  40,162,559
# 3                        5                         bad habits  37,799,456
# 4                        1  industry baby (feat. jack harlow)  33,948,454
#
#            Artist                track_ID  \
# 0        Måneskin  3Wrjm47oTz2sjIgck11l5e
# 1   The Kid LAROI  5HCyWlXZPP0y6Gqq8TgA20
# 2  Olivia Rodrigo  4ZtFanR9U6ndgddUvNcjcG
# 3      Ed Sheeran  6PQ88X9TkUIAUIZJHW2upE
# 4       Lil Nas X  27NovPIUIRrOZoCHxABJwK
#
#                                     Genre album_release_date Popularity  \
# 0  ['indie rock italiano', 'italian pop']         2017-12-08        100
# 1                  ['australian hip hop']         2021-07-09         99
# ...

# %%
df1.columns
# Out:
# Index(['Number of Times Charted', 'track_name', 'Streams', 'Artist',
#        'track_ID', 'Genre', 'album_release_date', 'Popularity', 'Danceability',
#        'Duration (ms)'],
#       dtype='object')

# %%
# Eliminamos las columnas que no tienen uso en el análisis
df2 = df2.drop(columns=[
    "track_number",
    "explicit",
    "track_popularity",
    "album_total_tracks"
])

# %%
df1 = df1.drop(columns=["Duration (ms)"])

# %%
df1.columns
# Out:
# Index(['Number of Times Charted', 'track_name', 'Streams', 'Artist',
#        'track_ID', 'Genre', 'album_release_date', 'Popularity',
#        'Danceability'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['track_id', 'track_name', 'Artist', 'artist_popularity',
#        'artist_followers', 'artist_genres', 'album_id', 'album_name',
#        'album_release_date', 'album_type', 'track_duration_min'],
#       dtype='object')
